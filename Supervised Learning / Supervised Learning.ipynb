# %% [markdown]
# ## Обучение с учителем: качество модели

# %% [markdown]
# ### Описание проекта

# %% [markdown]
# Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории. Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.
#
# «В один клик» — современная компания, поэтому её руководство не хочет принимать решения просто так — только на основе анализа данных и бизнес-моделирования. У компании есть небольшой отдел цифровых технологий, и вам предстоит побыть в роли стажёра в этом отделе.
#
# Итак, вашему отделу поручили разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.

# %% [markdown]
# ### Как решать задачу

# %% [markdown]
# Продумывать подход к решению этой задачи вам не придётся — руководитель отдела его уже сформировал:
# 1. Нужно промаркировать уровень финансовой активности постоянных покупателей. В компании принято выделять два уровня активности: **«снизилась»**, если клиент стал покупать меньше товаров, и **«прежний уровень»**.
#
#
# 2. Нужно собрать данные по клиентам по следующим группам:
#  - Признаки, которые описывают коммуникацию сотрудников компании с клиентом.
#  - Признаки, которые описывают продуктовое поведение покупателя. Например, какие товары покупает и как часто.
#  - Признаки, которые описывают покупательское поведение клиента. Например, сколько тратил в магазине.
#  - Признаки, которые описывают поведение покупателя на сайте. Например, как много страниц просматривает и сколько времени проводит на сайте.

# %% [markdown]
# ### Описание данных

# %% [markdown]
# **market_file.csv**
#
# Таблица, которая содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
# - id — номер покупателя в корпоративной базе данных.
# - Покупательская активность — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
# - Тип сервиса — уровень сервиса, например «премиум» и «стандарт».
# - Разрешить сообщать — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
# - Маркет_актив_6_мес — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.
# - Маркет_актив_тек_мес — количество маркетинговых коммуникаций в текущем месяце.
# - Длительность — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
# - Акционные_покупки — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
# - Популярная_категория — самая популярная категория товаров у покупателя за последние 6 месяцев.
# - Средний_просмотр_категорий_за_визит — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
# - Неоплаченные_продукты_штук_квартал — общее число неоплаченных товаров в корзине за последние 3 месяца.
# - Ошибка_сервиса — число сбоев, которые коснулись покупателя во время посещения сайта.
# - Страниц_за_визит — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.

# %% [markdown]
# **market_money.csv**
#
# Таблица с данными о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
# - id — номер покупателя в корпоративной базе данных.
# - Период — название периода, во время которого зафиксирована выручка. Например, 'текущий_месяц' или 'предыдущий_месяц'.
# - Выручка — сумма выручки за период.

# %% [markdown]
# **market_time.csv**
#
# Таблица с данными о времени (в минутах), которое покупатель провёл на сайте в течение периода.
# - id — номер покупателя в корпоративной базе данных.
# - Период — название периода, во время которого зафиксировано общее время.
# - минут — значение времени, проведённого на сайте, в минутах.

# %% [markdown]
# **money.csv**
#
# Таблица с данными о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
# - id — номер покупателя в корпоративной базе данных.
# - Прибыль — значение прибыли.

# %% [markdown]
# ### План работы

# %% [markdown]
# #### Шаг 1. Загрузка данных
# Загрузим файлы market_file.csv, market_money.csv, market_time.csv, money.csv
#
# #### Шаг 2. Предобработка данных
# Проведем предобработку данных, названия столбцов оставим кириллическими.
#
# #### Шаг 3. Исследовательский анализ данных
# Отберем клиентов с покупательской активностью не менее трёх месяцев, то есть таких, которые что-либо покупали в этот период.
#
# #### Шаг 4. Объединение таблиц
# Объединим таблицы market_file.csv, market_money.csv, market_time.csv.
#
# #### Шаг 5. Корреляционный анализ
# Проведем корреляционный анализ признаков в количественной шкале в итоговой таблице для моделирования.
#
# #### Шаг 6. Использование пайплайнов
# Применим модели KNeighborsClassifier(), DecisionTreeClassifier(), LogisticRegression() и  SVC() с использованием пайплайнов. Выберем лучшую модель.
#
# #### Шаг 7. Анализ важности признаков
# Оценим важность признаков для лучшей модели и построим график важности с помощью метода SHAP.
#
# #### Шаг 8. Сегментация покупателей
# Выберем группу покупателей и предложим, как увеличить её покупательскую активность.
#
# #### Шаг 9. Общие выводы
# Подытожим выводы по всем предыдущим шагам, дадим рекомендации для бизнеса исходя из задач.

# %% [markdown]
# ### Импорт библиотек и собственные функции

# %%
# !pip install phik -q
# !pip install shap -q

import pandas as pd
import numpy as np
from scipy.stats import shapiro
import matplotlib.pyplot as plt
from termcolor import colored
import seaborn as sns
import shap
from phik import phik_matrix
from phik.report import plot_correlation_matrix

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.dummy import DummyClassifier
from sklearn.inspection import permutation_importance
from sklearn.pipeline import Pipeline

from sklearn.compose import ColumnTransformer

from sklearn.preprocessing import (
    OneHotEncoder, 
    OrdinalEncoder, 
    StandardScaler, 
    MinMaxScaler, 
    RobustScaler,
    LabelEncoder
)

from sklearn.metrics import (
    f1_score, 
    roc_auc_score, 
    accuracy_score, 
    precision_score, 
    recall_score, 
    confusion_matrix, 
    ConfusionMatrixDisplay, 
    classification_report)

pd.options.mode.chained_assignment = None
import ssl
import urllib.request

ssl._create_default_https_context = ssl._create_unverified_context
# Out:
# zsh:1: /usr/local/bin/pip: bad interpreter: /System/Library/Frameworks/Python.framework/Versions/2.7/Resources/Python.app/Contents/MacOS/Python: no such file or directory
# WARNING: Error parsing dependencies of dexplot: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     scipy (>=1.0matplotlib>=3.1)
#           ~~~~~~^
# WARNING: Error parsing dependencies of ipykernel: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     matplotlib-inline (<0.2.0appnope,>=0.1.0) ; platform_system == "Darwin"
#                       ~~~~~~~~^
# zsh:1: /usr/local/bin/pip: bad interpreter: /System/Library/Frameworks/Python.framework/Versions/2.7/Resources/Python.app/Contents/MacOS/Python: no such file or directory
# WARNING: Error parsing dependencies of dexplot: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     scipy (>=1.0matplotlib>=3.1)
#           ~~~~~~^
# ...

# %%
#функция для вывода первичной информации
def quick_info(df_list):
    for df in df_list:
        print(colored('Общая информация:', 'red', attrs=['bold']))
        print(df.info())
        print(colored('Статистика по числовым данным:', 'red', attrs=['bold']))
        print(df.describe())
        print(colored('Дубликаты:', 'red', attrs=['bold']))
        print(df.duplicated().sum())
    
#функция для построения гистограммы и ящика с усами для каждого количественного признака
def histbox(df, exclude_cols=[], bins=80, figsize=(15, 5), title_fontsize=14, axis_fontsize=12):
    
    #Оставим только количественные признаки и исключим колонки в exclude_cols
    numeric_features = df.drop(columns=exclude_cols).select_dtypes(include=[np.number]).columns.tolist()

    #Определим под сабплоты количество строк и столбцов
    num_rows = len(numeric_features)
    num_cols = 2  # Для гистограммы и ящика с усами

    fig, axes = plt.subplots(num_rows, num_cols, figsize=figsize)
    
    #Гистограммы и ящики с усами
    for i, feature in enumerate(numeric_features):
        if df[feature].nunique() > 10:
            sns.histplot(df[feature], bins=bins, ax=axes[i, 0])
        else:
            sns.countplot(x=df[feature], ax=axes[i, 0], data=df)
        axes[i, 0].set_title(f'Гистограмма для \n{feature}', fontsize=title_fontsize)
        axes[i, 0].tick_params(axis='both', labelsize=axis_fontsize)

        sns.boxplot(x=df[feature], ax=axes[i, 1], data=df)
        axes[i, 1].set_title(f'Боксплот для \n{feature}', fontsize=title_fontsize)
        axes[i, 1].tick_params(axis='both', labelsize=axis_fontsize)

    plt.tight_layout()
    plt.show()


#функция для построения столбчатой и круговой диаграммы для каждого категориального признака 
def catplot(df, exclude_cols=[], figsize=(15, 5), title_fontsize=14, axis_fontsize=12):
    
    #Оставим только категориальные признаки и исключим колонки, указанные в exclude_cols
    cat_features = df.drop(columns=exclude_cols).select_dtypes(include='object').columns.tolist()

    #Создадим subplots
    num_rows = len(cat_features)
    fig, axes = plt.subplots(num_rows, 2, figsize=figsize)

    # Построим столбчатые и круговые диаграммы
    for i, feature in enumerate(cat_features):
        sns.countplot(x=feature, data=df, ax=axes[i, 0])
        axes[i, 0].set_title(f'Столбчатая диаграмма для \n{feature}', fontsize=title_fontsize)
        axes[i, 0].set_xlabel('')
        axes[i, 0].set_ylabel('Количество', fontsize=axis_fontsize)
        axes[i, 0].tick_params(axis='both', labelsize=axis_fontsize)
        axes[i, 0].set_xticklabels(axes[i, 0].get_xticklabels(), rotation=30)

        df[feature].value_counts().plot(kind='pie', autopct='%1.1f%%', ax=axes[i, 1], startangle=90)
        axes[i, 1].set_title(f'Круговая диаграмма для \n{feature}', fontsize=title_fontsize)
        axes[i, 1].set_ylabel('')
        axes[i, 1].tick_params(axis='both', labelsize=axis_fontsize)
        axes[i, 1].set_xticklabels(axes[i, 1].get_xticklabels(), rotation=30)

    plt.tight_layout()
    plt.show()


#функция для подсчета метрик модели
def evaluate_model(clf, X_train, y_train, X_test, y_test):
    # Кросс-валидация и вычисление ROC-AUC
    roc_auc_cv = cross_val_score(clf, X_train, y_train, scoring='roc_auc').mean()
    y_test_proba = clf.predict_proba(X_test)[:, 1]
    
    # Оценка accuracy
    acc_test = accuracy_score(y_test, clf.predict(X_test))
    
    # Оценка F1-score
    f1_test = f1_score(y_test, clf.predict(X_test))
    
    # Оценка ROC_AUC 
    roc_auc_test = roc_auc_score(y_test, y_test_proba)
    
    return roc_auc_cv, roc_auc_test, acc_test, f1_test

# %% [markdown]
# ## Шаг 1. Загрузка и знакомство с данными

# %% [markdown]
# Загрузим все четыре датафрейма и изучим с помощью нашей функции.

# %%
try:
    df_market_file = pd.read_csv('/Users/macbookpro/Desktop/market_file.csv', sep=',', decimal='.')
    df_market_money = pd.read_csv('/Users/macbookpro/Desktop/market_money.csv', sep=',', decimal='.')
    df_market_time = pd.read_csv('/Users/macbookpro/Desktop/market_time.csv', sep=',', decimal='.')
    df_money = pd.read_csv('/Users/macbookpro/Desktop/money.csv', sep=';', decimal=',')
except:
    df_market_file = pd.read_csv('https://code.s3.yandex.net/datasets/market_file.csv', sep=',', decimal='.')
    df_market_money = pd.read_csv('https://code.s3.yandex.net/datasets/market_money.csv', sep=',', decimal='.')
    df_market_time = pd.read_csv('https://code.s3.yandex.net/datasets/market_time.csv', sep=',', decimal='.')
    df_money = pd.read_csv('https://code.s3.yandex.net/datasets/money.csv', sep=';', decimal=',')

# %%
all_df = [df_market_file, df_market_money, df_market_time, df_money]

quick_info(all_df)
# Out:
# Общая информация:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   Покупательская активность            1300 non-null   object
#  2   Тип сервиса                          1300 non-null   object
#  3   Разрешить сообщать                   1300 non-null   object
#  4   Маркет_актив_6_мес                   1300 non-null   float64
#  5   Маркет_актив_тек_мес                 1300 non-null   int64
#  6   Длительность                         1300 non-null   int64
#  7   Акционные_покупки                    1300 non-null   float64
#  8   Популярная_категория                 1300 non-null   object
#  9   Средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  Неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %% [markdown]
# #### Анализ данных по функции describe():

# %% [markdown]
# - Датафрейм `df_market_file`: возможные выбросы (столбцы, в которых медиана и среднее значение сильно отличаются): акционные_покупки, длительность, средний_просмотр_категорий_за_визит, неоплаченные_продукты_штук_квартал, ошибка_сервиса, страниц_за_визит. Логически все-таки думаю, что это не выбросы, а сильные различия в поведении разных сегментов пользователей. Пропусков в датафрейме нет.
#
# - Датафрейм `df_market_money`: видим крайне сильное отличие медианы и среднего значения у выручки: скорее всего, это означает аномальные значения. Пропусков в датафрейме нет.
#
# - Датафрейм `df_market_time` и `df_money`: аномалий и пропусков в датафреймах нет.

# %% [markdown]
# ### Выводы:
#
# 1. В датафрейме market_file 13 столбцов и 1300 id покупателей. Исходя из первичного анализа, в нем нет пропусков и явных дубликатов. Но названия столбцов стоит унифицировать и привести к "змеиному регистру". Еще видим, что в типе сервиса категория "стандарт" превратилась в "стандартт".
#
#
# 2. В датафрейме market_money три столбца и 3900 строк. Пропусков и явных дубликатов в нем тоже не видно.
#
#
# 3. В датафрейме market_time три столбца и 2600 строк. Пропусков и явных дубликатов в нем не обнаружили, но есть опечатки в категориях вроде "предыдцщий_месяц".
#
#
# 4. В датафрейме money два столбца и 1300 строк. Пропусков и явных дубликатов в нем не обнаружили.
#
#
# 5. Во всех датафреймах данные соответствуют своему типу, так что изменять их не будем.

# %% [markdown]
# ## Шаг 2. Предобработка данных

# %% [markdown]
# Создадим цикл, чтобы привести столбцы к "змеиному регистру" и избавиться от пробелов в названиях. Выведем первые две строки датафреймов для проверки названий столбцов.

# %%
for df in all_df:
    df.columns = [x.lower() for x in df.columns]
    df.columns = [x.replace(' ', '_') for x in df.columns]
    display(df.head(2))
# Out:
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 3.4                     5           121               0.00
# 1                 4.4                     4           819               0.75
#
#   популярная_категория  средний_просмотр_категорий_за_визит  \
# 0     Товары для детей                                    6
# 1     Товары для детей                                    4
#
#    неоплаченные_продукты_штук_квартал  ошибка_сервиса  страниц_за_визит
# 0                                   2               1                 5
# 1                                   4               2                 5
#        id               период  выручка
# 0  215348  препредыдущий_месяц      0.0
# 1  215348        текущий_месяц   3293.1
# ...

# %% [markdown]
# Теперь проверим market_file на неявные дубликаты. Для этого создадим цикл, который позволит вывести уникальные значения каждого категориального столбца датафрейма.

# %%
print(colored('Проверка уникальных значений категориальных столбцов "df_market_file":\n', 'red', attrs=['bold']))
for col in df_market_file.select_dtypes(exclude='number').columns:
    unique_values = df_market_file[col].value_counts()
    num_unique_values = len(df_market_file[col].unique())
    
    print(f'Уникальные значения для столбца "{col}":\n{unique_values}\n')
    print(f'Количество уникальных значений столбца "{col}": {num_unique_values}')
    print(f'Количество уникальных id в датафрейме: {df_market_file.id.value_counts().sum()}')
# Out:
# Проверка уникальных значений категориальных столбцов "df_market_file":
#
# Уникальные значения для столбца "покупательская_активность":
# Прежний уровень    802
# Снизилась          498
# Name: покупательская_активность, dtype: int64
#
# Количество уникальных значений столбца "покупательская_активность": 2
# Количество уникальных id в датафрейме: 1300
# Уникальные значения для столбца "тип_сервиса":
# стандарт     914
# премиум      376
# стандартт     10
# Name: тип_сервиса, dtype: int64
#
# Количество уникальных значений столбца "тип_сервиса": 3
# Количество уникальных id в датафрейме: 1300
# Уникальные значения для столбца "разрешить_сообщать":
# да     962
# нет    338
# Name: разрешить_сообщать, dtype: int64
#
# Количество уникальных значений столбца "разрешить_сообщать": 2
# Количество уникальных id в датафрейме: 1300
# Уникальные значения для столбца "популярная_категория":
# Товары для детей                        330
# Домашний текстиль                       251
# ...

# %% [markdown]
# Мы видим, что в столбце с покупательской активностью есть значение "стандартт", а в популярных категориях есть значение "аксесуары": исправим это. Кроме того, приведем для унификации все уникальные значения в категориальных столбцах к "змеиному регистру".

# %%
df_market_file['тип_сервиса'] = df_market_file['тип_сервиса'].str.replace('стандартт', 'стандарт')
df_market_file['популярная_категория'] = df_market_file['популярная_категория'].str.replace('Косметика и аксесуары', 
                                                                                            'Косметика и аксессуары')
print('Столбец "тип_сервиса":')
print(df_market_file['тип_сервиса'].value_counts())
print()
print('Столбец "популярная_категория":')
print(df_market_file['популярная_категория'].value_counts())
# Out:
# Столбец "тип_сервиса":
# стандарт    924
# премиум     376
# Name: тип_сервиса, dtype: int64
#
# Столбец "популярная_категория":
# Товары для детей                        330
# Домашний текстиль                       251
# Косметика и аксессуары                  223
# Техника для красоты и здоровья          184
# Мелкая бытовая техника и электроника    174
# Кухонная посуда                         138
# Name: популярная_категория, dtype: int64

# %% [markdown]
# C первым датафреймом разобрались, теперь неявных дубликатов и опечаток нет, а значения унифицированы. Перейдем к df_market_money.

# %%
print(colored('Проверка уникальных значений категориальных столбцов "df_market_money":\n', 
              'red', attrs=['bold']))
for col in df_market_money.select_dtypes(exclude='number').columns:
    unique_values = df_market_money[col].value_counts()
    num_unique_values = len(df_market_money[col].unique())
    
    print(f'Уникальные значения для столбца "{col}":\n{unique_values}\n')
    print(f'Количество уникальных значений столбца "{col}": {num_unique_values}')
    print(f'Количество уникальных id в датафрейме: {df_market_money.id.value_counts().sum()}')
# Out:
# Проверка уникальных значений категориальных столбцов "df_market_money":
#
# Уникальные значения для столбца "период":
# предыдущий_месяц       1300
# препредыдущий_месяц    1300
# текущий_месяц          1300
# Name: период, dtype: int64
#
# Количество уникальных значений столбца "период": 3
# Количество уникальных id в датафрейме: 3900

# %% [markdown]
# Неявных дубликатов нет, но исправим "препредыдущий_месяц" на "предпредыдущий_месяц":

# %%
df_market_money['период'] = df_market_money['период'].str.replace(
    'препредыдущий_месяц', 'предпредыдущий_месяц')

print('Столбец "период":')
df_market_money['период'].value_counts()
# Out:
# Столбец "период":
# предпредыдущий_месяц    1300
# предыдущий_месяц        1300
# текущий_месяц           1300
# Name: период, dtype: int64

# %% [markdown]
# Проведем такую же проверку на неявные дубликаты для df_market_time:

# %%
print(colored('Проверка уникальных значений категориальных столбцов "df_market_time":\n', 
              'red', attrs=['bold']))
for col in df_market_time.select_dtypes(exclude='number').columns:
    unique_values = df_market_time[col].value_counts()
    num_unique_values = len(df_market_time[col].unique())
    
    print(f'Уникальные значения для столбца "{col}":\n{unique_values}\n')
    print(f'Количество уникальных значений столбца "{col}": {num_unique_values}')
    print(f'Количество уникальных id в датафрейме: {df_market_time.id.value_counts().sum()}')
# Out:
# Проверка уникальных значений категориальных столбцов "df_market_time":
#
# Уникальные значения для столбца "период":
# предыдцщий_месяц    1300
# текущий_месяц       1300
# Name: период, dtype: int64
#
# Количество уникальных значений столбца "период": 2
# Количество уникальных id в датафрейме: 2600

# %% [markdown]
# Неявных дубликатов нет, но исправим "предыдцщий_месяц" на "предыдущий_месяц":

# %%
df_market_time['период'] = df_market_time['период'].str.replace(
    'предыдцщий_месяц', 'предыдущий_месяц')

print('Столбец "период":')
df_market_time['период'].value_counts()
# Out:
# Столбец "период":
# предыдущий_месяц    1300
# текущий_месяц       1300
# Name: период, dtype: int64

# %% [markdown]
# Проведем проверку на неявные дубликаты для df_money:

# %%
# выведем типы данных в столбцах df_money
print(f'Типы данных столбцов "df_money":\n{df_money.dtypes}\n')

# проверим только столбец 'id'    
print('Количество уникальных значений столбца "id":', len(df_money['id'].unique()))
# Out:
# Типы данных столбцов "df_money":
# id           int64
# прибыль    float64
# dtype: object
#
# Количество уникальных значений столбца "id": 1300

# %% [markdown]
# Не обнаружили неявные дубликаты, число уникальных id совпадает с уникальными id в market_file.

# %% [markdown]
# ### Выводы:
#
# 1. Привели столбцы во всех датафреймах к "змеиному регистру" и избавились от пробелов в названиях.
#
#
# 2. Проверили датафреймы на неявные дубликаты и избавились от них.
#
#
# 3. Проверили, верны ли типы данных в датафреймах. Проблем с ними не обнаружили.

# %% [markdown]
# ## Шаг 3. Исследовательский анализ данных

# %% [markdown]
# Проведем исследовательский анализ числовых данных в market_file:

# %%
histbox(
    df_market_file, 
    exclude_cols=['id'], 
    bins=50, figsize=(10, 20), 
    title_fontsize=10, 
    axis_fontsize=5
)

df_market_file.describe()
# Out:
#                   id  маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# count    1300.000000         1300.000000           1300.000000   1300.000000
# mean   215997.500000            4.253769              4.011538    601.898462
# std       375.421985            1.014814              0.696868    249.856289
# min    215348.000000            0.900000              3.000000    110.000000
# 25%    215672.750000            3.700000              4.000000    405.500000
# 50%    215997.500000            4.200000              4.000000    606.000000
# 75%    216322.250000            4.900000              4.000000    806.000000
# max    216647.000000            6.600000              5.000000   1079.000000
#
#        акционные_покупки  средний_просмотр_категорий_за_визит  \
# count        1300.000000                           1300.00000
# mean            0.319808                              3.27000
# std             0.249843                              1.35535
# ...

# %% [markdown]
# ### Промежуточные выводы по распределению числовых признаков `df_market_file`:
#
# - **маркет_актив_6 мес**: распределение стремится к нормальному с небольшими пиками. Среднее 4.25, медиана 4.2, min 0.9, max 6.6
#
# - **маркет_актив_тек_мес**: мультимодальное распределение с пиками 3.0, 4.0 и 5.0. Среднее 4.01, медиана 4, min 3, max 5
#
# - **длительность**: распределение стремится к нормальному с небольшими пиками на 200, 500, около 800. Среднее 601.9, медиана 606, min 110, max 1079.
#
# - **акционные_покупки**: бимодальное распределение. Есть пользователи, которые покупали преимущественно по акции за период. Среднее 0.32, медиана 0.24, min 0, max 0.99.
#
# - **средний_просмотр_категорий_за_визит**: распределение стремится к нормальному. Среднее 3.27, медиана 3, min 1, max 6
#
# - **неоплаченные_продукты_штук_квартал**: распределение стремится к нормальному, но ассиметрично со сдвигом на левую сторону. Среднее 2.84, медиана 3, min 0, max 10
#
# - **ошибка_сервиса**: распределение стремится к нормальному. Среднее 4.19, медиана 4, min 0, max 9
#
# - **страниц_за_визит**: распределение стремится к нормальному. Среднее 8.18, медиана 8, min 1, max 20

# %%
stat, p = shapiro(df_market_file['страниц_за_визит'])
print('stat=%.3f, p=%.3f\n' % (stat, p))
if p > 0.05:
    print('Скорее всего, нормальное')
else:
    print('Скорее всего, ненормальное')
# Out:
# stat=0.974, p=0.000
#
# Скорее всего, ненормальное

# %% [markdown]
# Проведем исследовательский анализ категориальных данных в market_file:

# %%
catplot(df_market_file,  
    figsize=(19, 25), 
    title_fontsize=10, 
    axis_fontsize=8
)

# %% [markdown]
# ### Промежуточные выводы по распределению категориальных признаков `df_market_file`:
#
# - **покупательская активность**: метрика за период снизилась у 38.3% пользователей
#
# - **тип сервиса**: пользователей с уровнем сервиса "стандарт" больше: 71.1%
#
# - **разрешить сообщать**: пользователи чаще дают согласие на дополнительные сообщения (74%).
#
# - **популярная категория**: топ-3 популярных категорий за период: товары для детей, домашний текстиль, косметика и аксессуары.

# %% [markdown]
# Проведем исследовательский анализ числовых данных в market_money:

# %%
histplot = sns.histplot(df_market_money['выручка'], bins=30)
histplot.set_title('Гистограмма для выручки', fontsize=10)
histplot.set_xlabel('Выручка', fontsize=8)

df_market_money.describe()
# Out:
#                   id        выручка
# count    3900.000000    3900.000000
# mean   215997.500000    5025.696051
# std       375.325686    1777.704104
# min    215348.000000       0.000000
# 25%    215672.750000    4590.150000
# 50%    215997.500000    4957.500000
# 75%    216322.250000    5363.000000
# max    216647.000000  106862.200000

# %% [markdown]
# График отображается некорректно из-за слишком большого максимального значения (106862) при минимальном значении 0. Попробуем исключить эти значения при исследовательском анализе:

# %%
df_market_money_norm = df_market_money.query('0 < выручка < 106862.2')

histplot = sns.histplot(df_market_money_norm['выручка'], bins=30)
histplot.set_title('Гистограмма для выручки', fontsize=10)
histplot.set_xlabel('Выручка', fontsize=8)

df_market_money_norm.describe()
# Out:
#                   id      выручка
# count    3893.000000  3893.000000
# mean   215998.649371  5007.282918
# std       374.681667   679.724898
# min    215348.000000  2758.700000
# 25%    215674.000000  4592.000000
# 50%    215999.000000  4959.000000
# 75%    216323.000000  5363.000000
# max    216647.000000  7799.400000

# %% [markdown]
# ### Промежуточные выводы по распределению числовых признаков `df_market_money`:

# %% [markdown]
# **выручка**: мы видим, что без максимального значения распределение нормальное с пиком около 5000. Среднее 5007.28, медиана 4959.

# %% [markdown]
# Проведем исследовательский анализ категориальных данных в market_money:

# %%
data_counts = df_market_money['период'].value_counts()
fig, axes = plt.subplots(1, 2, figsize=(10, 6))

axes[0].pie(data_counts, labels=data_counts.index, autopct='%1.1f%%', startangle=140)
axes[0].set_title('Круговая диаграмма для периода')

sns.barplot(x=data_counts.index, y=data_counts.values, ax=axes[1], palette='viridis')
axes[1].set_title('Столбчатая диаграмма для периода')
axes[1].tick_params(axis='x', rotation=50)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Промежуточные выводы по распределению категориальных признаков `df_market_money`:

# %% [markdown]
# **период**: мы видим, что данные по выручке с пользователей распределены поровну между тремя месяцами

# %% [markdown]
# Проведем исследовательский анализ числовых данных в money:

# %%
histplot = sns.histplot(df_money['прибыль'], bins=30)
histplot.set_title('Гистограмма для прибыли', fontsize=10)
histplot.set_xlabel('Прибыль', fontsize=8)

df_money.describe()
# Out:
#                   id      прибыль
# count    1300.000000  1300.000000
# mean   215997.500000     3.996631
# std       375.421985     1.013722
# min    215348.000000     0.860000
# 25%    215672.750000     3.300000
# 50%    215997.500000     4.045000
# 75%    216322.250000     4.670000
# max    216647.000000     7.430000

# %% [markdown]
# ### Промежуточные выводы по распределению числовых признаков `df_money`:

# %% [markdown]
# **прибыль**: распределение нормальное с пиком около 4. Среднее 3.99, медиана 4.04, min 0.86, max 7.43

# %% [markdown]
#  Проведем исследовательский анализ числовых данных в time:

# %%
histplot = sns.histplot(df_market_time['минут'], bins=30)
histplot.set_title('Гистограмма для минут на сайте', fontsize=10)
histplot.set_xlabel('Минуты на сайте', fontsize=8)

df_market_time.describe()
# Out:
#                   id        минут
# count    2600.000000  2600.000000
# mean   215997.500000    13.336154
# std       375.349754     4.080198
# min    215348.000000     4.000000
# 25%    215672.750000    10.000000
# 50%    215997.500000    13.000000
# 75%    216322.250000    16.000000
# max    216647.000000    23.000000

# %% [markdown]
# ### Промежуточные выводы по распределению числовых признаков `df_market_time`:

# %% [markdown]
# **минуты**: распределение близко к нормальному. Среднее 13.33, медиана 13, min 4, max 23

# %% [markdown]
#  Проведем исследовательский анализ категориальных данных в time:

# %%
data_counts = df_market_time['период'].value_counts()
fig, axes = plt.subplots(1, 2, figsize=(10, 6))

axes[0].pie(data_counts, labels=data_counts.index, autopct='%1.1f%%', startangle=140)
axes[0].set_title('Круговая диаграмма для периода')

sns.barplot(x=data_counts.index, y=data_counts.values, ax=axes[1], palette='viridis')
axes[1].set_title('Столбчатая диаграмма для периода')
axes[1].tick_params(axis='x', rotation=50)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Промежуточные выводы по распределению категориальных признаков `df_market_time`:
#
# **период**: данные о времени, которое пользователь провел на сайте, распределены поровну между предыдущим и текущим месяцем.

# %% [markdown]
# ### Отберём клиентов с покупательской активностью не менее трёх месяцев

# %% [markdown]
# Так как покупательская активность характеризуется выручкой с пользователя, будем использовать df_market_money. В этом датафрейме есть данные за текущий, предыдущий и препредыдущий месяцы. Нужно найти пользователей, которые делали покупки в каждый из этих месяцев.

# %%
#ищем id пользователей, которые вообще не совершали покупок
inactive_users_ids = df_market_money.loc[(df_market_money['выручка'] == 0),'id'].unique()
print(f'ID пользователей с непостоянной активностью: {inactive_users_ids}')

active_users_ids = df_market_money[~df_market_money['id'].isin(inactive_users_ids)]
print('Количество активных пользователей за последние три месяца:', active_users_ids['id'].nunique())
print('Строк после отсеивания пользователей с непостоянной активностью:', len(active_users_ids))
df_market_money = df_market_money[~df_market_money.id.isin(inactive_users_ids)]
# Out:
# ID пользователей с непостоянной активностью: [215348 215357 215359]
# Количество активных пользователей за последние три месяца: 1297
# Строк после отсеивания пользователей с непостоянной активностью: 3891

# %% [markdown]
# Удостоверимся, что удалили пользователя с аномальной максимальной выручкой:

# %%
id_to_delete = df_market_money[df_market_money['выручка'] >= 106000]['id'].tolist()

#избавляемся от выброса
#удалим данные о всех периодах для выбранного пользователя
df_market_money = df_market_money.query('выручка != @id_to_delete')

# проверяем
print('Количество пользователей после чистки от аномалии:', df_market_money['id'].nunique())
display(df_market_money.describe())
# Out:
# Количество пользователей после чистки от аномалии: 1297
#                   id        выручка
# count    3891.000000    3891.000000
# mean   215998.986893    5033.718890
# std       374.482249    1768.471286
# min    215349.000000    2758.700000
# 25%    215675.000000    4592.000000
# 50%    215999.000000    4959.000000
# 75%    216323.000000    5363.200000
# max    216647.000000  106862.200000

# %% [markdown]
# ### Выводы:
#
# Изучили, визуализировали и описали числовые и категориальные признаки в имеющихся датафреймах с помощью гистограмм, боксплотов, столбчатых и круговых диаграмм.
#
# 1. `df_market_file`:
# - **маркет_актив_6 мес**: распределение близко к нормальному с небольшими пиками. Среднее 4.25, медиана 4.2, min 0.9, max 6.6
#
# - **маркет_актив_тек_мес**: мультимодальное распределение с пиками 3.0, 4.0 и 5.0. Среднее 4.01, медиана 4, min 3, max 5
#
# - **длительность**: распределение стремится к нормальному с небольшими пиками на 200, 500, около 800. Среднее 601.9, медиана 606, min 110, max 1079.
#
# - **акционные_покупки**: бимодальное распределение. Есть пользователи, которые покупали преимущественно по акции за период. Среднее 0.32, медиана 0.24, min 0, max 0.99.
#
# - **средний_просмотр_категорий_за_визит**: распределение похоже на нормальное. Среднее 3.27, медиана 3, min 1, max 6
#
# - **неоплаченные_продукты_штук_квартал**: распределение близко к нормальному, но ассиметрично со сдвигом на левую сторону. Среднее 2.84, медиана 3, min 0, max 10
#
# - **ошибка_сервиса**: распределение похоже на нормальное. Среднее 4.19, медиана 4, min 0, max 9
#
# - **страниц_за_визит**: распределение похоже на нормальное. Среднее 8.18, медиана 8, min 1, max 20
# - **Покупательская активность**: большинство пользователей (61.7%) имеют прежний уровень
# - **Тип сервиса**: пользователей с уровнем сервиса "стандарт" больше: 71.1%
# - **Разрешить сообщать**: пользователи чаще дают согласие на дополнительные сообщения (74%).
# - **Популярная категория**: топ-3 популярных категорий за период: товары для детей, домашний текстиль, косметика и аксессуары.
#
#
# 2. `df_market_money`:
#
# - **выручка**: мы видим, что без максимального значения распределение нормальное с пиком около 5000. Среднее 5007.28, медиана 4959. Было аномальное максимальное значение, сразу удалили его.
#
# - **период**: мы видим, что данные по выручке с пользователей распределены поровну между тремя месяцами
#
#
# 3. `df_money`:
# - **прибыль**: распределение нормальное с пиком около 4. Среднее 3.99, медиана 4.04, min 0.86, max 7.43
#
# 4. `df_market_time`:
# - **минуты**: распределение близко к нормальному. Среднее 13.33, медиана 13, min 4, max 23
# - **период**: данные о времени, которое пользователь провел на сайте, распределены поровну между предыдущим и текущим месяцем.
#
# Удалось также отобрать пользователей с ежемесячной покупательской активностью: active_users_ids. Их число после удаления аномалии: 1297. Исключили пользователей с непостоянной покупательской активностью (тех, которые не совершали покупки ежемесячно на протяжении последних трёх месяцев).

# %% [markdown]
# ## Шаг 4. Объединение таблиц

# %% [markdown]
# Объединим таблицы df_market_file, df_market_money и df_market_time по id с помощью цикла для создания и присоединения данных для каждого периода.

# %%
periods = ['текущий_месяц', 'предыдущий_месяц', 'предпредыдущий_месяц']
periods_2 = ['текущий_месяц', 'предыдущий_месяц']

df_market_money_periods = []
df_market_time_periods = []

for period in periods:
    df_market_money_period = (df_market_money
                              .query(f'период == "{period}"')
                              .drop(['период'], axis=1)
                              .rename(columns={'выручка': f'выручка_{period}'}))
    df_market_money_periods.append(df_market_money_period)

for period in periods_2:
    df_market_time_period = (df_market_time
                             .query(f'период == "{period}"')
                             .drop(['период'], axis=1)
                             .rename(columns={'минут': f'минут_{period}'}))
    df_market_time_periods.append(df_market_time_period)

# Объединяем все DataFrame'ы из списка
df_merged_final = df_market_file.copy()  # Создаем копию df_market_file

for df_market_money_period in df_market_money_periods:
    df_merged_final = df_merged_final.merge(df_market_money_period, on='id')

for df_market_time_period in df_market_time_periods:
    df_merged_final = df_merged_final.merge(df_market_time_period, on='id')

df_merged_final.reset_index(drop=True, inplace=True)

print(df_merged_final.shape)
print(df_market_file.shape)
print(df_market_money.shape)
print(df_market_time.shape)
df_merged_final.head()
# Out:
# (1297, 18)
# (1300, 13)
# (3891, 3)
# (2600, 3)
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215349                 Снизилась     премиум                 да
# 1  215350                 Снизилась    стандарт                нет
# 2  215351                 Снизилась    стандарт                 да
# 3  215352                 Снизилась    стандарт                нет
# 4  215353                 Снизилась    стандарт                 да
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 4.4                     4           819               0.75
# 1                 4.9                     3           539               0.14
# 2                 3.2                     5           896               0.99
# 3                 5.1                     3          1064               0.94
# 4                 3.3                     4           762               0.26
#
# ...

# %% [markdown]
# ### Выводы:

# %% [markdown]
# - С помощью цикла мы объединили df_market_file, df_market_money и df_market_time и сохранили в переменную df_merged_final.
# - В итоговой таблице для каждого периода из df_market_money и df_market_time сделали отдельный столбец.
# - Она состоит из 18 столбцов и 1296 строк.

# %% [markdown]
# ## Шаг 5. Корреляционный анализ

# %% [markdown]
# Используем библиотеку phik для подсчёта корреляции между признаками разных типов данных:

# %%
interval_cols = ['маркет_актив_6_мес', 'длительность', 
                'акционные_покупки', 'неоплаченные_продукты_штук_квартал',
                'страниц_за_визит', 'выручка_текущий_месяц',
                'выручка_предыдущий_месяц', 
                'выручка_предпредыдущий_месяц',
                'минут_текущий_месяц',
                'минут_предыдущий_месяц']

phik_analysis = (
    df_merged_final
    .drop('id', axis=1)
    .phik_matrix(interval_cols = interval_cols, verbose=False))

# визуализируем матрицу и выводим на экран
plot_correlation_matrix(
    phik_analysis.values,
    x_labels=phik_analysis.columns,
    y_labels=phik_analysis.index,
    vmin=0, vmax=1, color_map='Greens',
    title=r'Корреляция $\phi_K$',
    fontsize_factor=1.5,
    figsize=(15, 10)
)

# %% [markdown]
# Наш целевой признак: **покупательская_активность**. Изучим, с какими входными признаками у него есть высокая корреляция:
#
# - **страниц_за_визит**: 0.75, самая высокая корреляция
# - **минут_предыдущий_месяц**: 0.69, близка к высокой
# - **минут_текущий_месяц**: 0.58, заметная корреляция
#
# При этом мультиколлинеарности с помощью подсчета хи-квадрат статистики не наблюдаем: ее можно было бы отметить при значениях коллинеарности от 0.9 до 1.

# %% [markdown]
# ### Выводы

# %% [markdown]
# Для корреляционного анализа признаков в количественной шкале в итоговой таблице для моделирования использовали библиотеку `phik`. Она позволяет вычислять взаимосвязи между различными типами признаков (категориальными, непрерывными и их комбинациями, поэтому не использовали другие инструменты корреляционного анализа.
#
# Удалось выяснить, что мультиколлинеарности с целевым признаком нет, несмотря на то, что есть входные признаки с высокой корреляцией.

# %% [markdown]
# <div style="background: #B0E0E3; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Большое спасибо за дополнительные материалы!

# %% [markdown]
# ## Шаг 6. Использование пайплайнов

# %% [markdown]
# По результатам исследовательского анализа мы помним, что в целевом признаке **покупательская_активность** есть дисбаланс классов. Они распределяются так: 61.7% пользователей имеют прежний уровень **(класс 0)**, активность 38.3% пользователей снизилась **(класс 1)**.

# %%
df_merged_final['покупательская_активность'].value_counts(normalize=True).plot(kind='bar')
plt.title('Дисбаланс классов в целевом признаке')
plt.show()

# %% [markdown]
# Если мы обучим модели на несбалансированных данных, то они могут лучше предсказывать мажорный класс (прежний уровень активности) и игнорировать снижение активности пользователей. Поэтому разделим данные с учётом страт.

# %%
#устанавливаем RANDOM_STATE и TEST_SIZE
RANDOM_STATE = 42
TEST_SIZE = 0.25

#выделим в отдельные переменные целевой признак и входные признаки
X = df_merged_final.drop(columns=['покупательская_активность', 'id'])
y = df_merged_final['покупательская_активность']

#разбиваем данные на выборки с учётом стратификации по целевому признаку
X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y, 
    random_state=RANDOM_STATE, 
    test_size=TEST_SIZE, 
    stratify=y
) 

# визуализируем баланс целевого признака в выборках
datasets = ['Исходный датафрейм', 'Train', 'Test']
fig, ax = plt.subplots(1, 3, figsize=(10, 5))
for i, dataset in enumerate([y, y_train, y_test]):
    dataset.value_counts().plot(kind='bar', ax=ax[i], rot=0)
    ax[i].set_title(datasets[i])

plt.show()
label_encoder = LabelEncoder()

y_train_le = label_encoder.fit_transform(y_train)
y_test_le = label_encoder.transform(y_test)

# %% [markdown]
# **Соберем следующий пайплайн:**
#
# 1. Обозначим, какие данные требуют масштабирования, а какие — кодирования, в ohe_columns, ord_columns и num_columns
# 2. Создадим пайплайны для подготовки признаков из списков ohe_columns и ord_columns с помощью OHE-кодирования
# 3. Создадим общий пайплайн data_preprocessor для подготовки данных
# 4. Создадим итоговый пайплайн pipe_final: подготовка данных и модель
# 5. С помощью `RandomizedSearchCV` найдем лучшую модель.
#
# **Какие модели будем использовать:**
#
# 1. `DecisionTreeClassifier()` с гиперпараметрами max_depth и max_features от 2 до 4 включительно
# 2. `KNeighborsClassifier()` с гиперпараметрами n_neighbors от 2 до 4 включительно
# 3. `LogisticRegression()` с решателем solver='liblinear' и лассо-регуляризацией с гиперпараметром С от 1 до 4 включительно
# 4. `SVC()` с ядрами kernel='linear' и 'rbf'

# %% [markdown]
# За метрику возьмем ROC AUC по следующим причинам:
#
# - Хорошо интерпретируется: отображает отношение между долей истинно положительных и долей ложно положительных классификаций при различных порогах
# - Отлично подходит для бинарной классификации с несбалансированной выборкой

# %%
ohe_columns = ['популярная_категория']
ord_columns = ['тип_сервиса', 'разрешить_сообщать']
num_columns = df_merged_final.drop(['id', 'популярная_категория', 
                                    'тип_сервиса', 'разрешить_сообщать', 'покупательская_активность'], axis=1).columns.tolist()

  
ohe_pipe = Pipeline(
    [
     ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False))
    ]
    )

ord_pipe = Pipeline(
    [
     ('ord',  OrdinalEncoder(
                categories=[
                    ['стандарт', 'премиум'], 
                    ['да', 'нет']
                ], 
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        ),
    ]
)

data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', MinMaxScaler(), num_columns),
    ], 
    remainder='passthrough'
)

pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

param_grid = [
    #словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 5),
        'models__max_features': range(2, 5), 
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler()]  
    },
    
    #словарь для модели KNeighborsClassifier() 
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler()]   
    },

    # словарь для модели LogisticRegression()
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE, 
            solver='liblinear', 
            penalty='l1'
        )],
        'models__C': range(1, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler()]  
    },
    # словарь для модели SVC()
    
    {
        'models': [SVC()],
        'models__C': range(1, 5),
        'models__kernel': ['linear', 'rbf'],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler()] 
    }
]

randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_grid, 
    cv=5,
    scoring='roc_auc',
    random_state=RANDOM_STATE,
    n_jobs=-1
)
randomized_search.fit(X_train, y_train)
print('Лучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
print(f'Параметры лучшей модели:\n{randomized_search.best_params_}')
print('Метрика лучшей модели на тренировочной выборке:', round(randomized_search.best_score_, 3))
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['популярная_категория']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('ord',
#                                                                    OrdinalEncoder(categories=[['стандарт',
# ...

# %%
# преобразовываем результаты в датафрейм и выводим результаты на экран
pd.DataFrame(randomized_search.cv_results_)[
    ['std_test_score', 'rank_test_score', 'param_models', 'mean_test_score','params']
].sort_values('rank_test_score')
# Out:
#    std_test_score  rank_test_score                             param_models  \
# 5        0.027414                1                                    SVC()
# 1        0.027456                2                                    SVC()
# 9        0.027435                3                                    SVC()
# 7        0.015061                4                   KNeighborsClassifier()
# 4        0.025192                5                   KNeighborsClassifier()
# 8        0.014574                6  DecisionTreeClassifier(random_state=42)
# 2        0.012356                7  DecisionTreeClassifier(random_state=42)
# 3        0.030929                8  DecisionTreeClassifier(random_state=42)
# 6        0.036954                9  DecisionTreeClassifier(random_state=42)
# 0        0.030248               10  DecisionTreeClassifier(random_state=42)
#
#    mean_test_score                                             params
# ...

# %% [markdown]
# ### Выводы

# %% [markdown]
# Мы построили пайплайн, который позволил выбрать лучшую комбинацию модели и гиперпараметров. Оценивали четыре модели:
#
# - DecisionTreeClassifier()
# - KNeighborsClassifier()
# - LogisticRegression()
# - SVC()
#
# Лучше всего себя показала модель SVC() с RobustScaler() и линеарным ядром. Метрика ROC-AUC лучшей модели на тренировочной выборке: 0.891.

# %% [markdown]
# ## Шаг 7. Анализ важности признаков

# %% [markdown]
# Оценим вклад признака в каждый прогноз с помощью метода SHAP. Для этого создадим пайплайн для подготовки данных, проверим размерность выборок, а затем обучим лучшую модель.

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('ohe', OneHotEncoder(sparse_output=False, drop='first'), ohe_columns),
        ('ord', OrdinalEncoder(), ord_columns),
        ('scaler', StandardScaler(), num_columns)
    ])

X_train_prep = preprocessor.fit_transform(X_train)
X_test_prep = preprocessor.transform(X_test)

ohe_encoder_col_names = preprocessor.named_transformers_['ohe'].get_feature_names_out(ohe_columns)
ord_encoder_col_names = preprocessor.named_transformers_['ord'].get_feature_names_out(ord_columns)

X_train_final = pd.DataFrame(X_train_prep, columns=np.concatenate([ohe_encoder_col_names, ord_encoder_col_names, num_columns]))
X_test_final = pd.DataFrame(X_test_prep, columns=np.concatenate([ohe_encoder_col_names, ord_encoder_col_names, num_columns]))

print('Размерности выборок:')
shape_data = {'Выборка': ['X_train_final', 'X_test_final', 'y_train', 'y_test'], 
              'Размер': [X_train_final.shape, X_test_final.shape, y_train.shape, y_test.shape]} 
display(pd.DataFrame(shape_data))
# Out:
# Размерности выборок:
#          Выборка     Размер
# 0  X_train_final  (972, 20)
# 1   X_test_final  (325, 20)
# 2        y_train     (972,)
# 3         y_test     (325,)

# %% [markdown]
# Обучим лучшую модель:

# %%
best_model = SVC(kernel='linear', C=1, probability=True, random_state=42)
best_model.fit(X_train_final, y_train_le)
y_pred = best_model.predict(X_test_final)

#Оценка модели
roc_auc_cv, roc_auc_test, acc_test, f1_test = evaluate_model(best_model, X_train_final, y_train_le, X_test_final, y_test_le)

#Результаты
print(f'ROC-AUC на тренировочной выборке: {roc_auc_cv:.3f}')
print(f'ROC-AUC на тестовой выборке: {roc_auc_test:.3f}')
print(f'Accuracy: {acc_test:.3f}')
print(f'F1-score: {f1_test:.3f}')
# Out:
# ROC-AUC на тренировочной выборке: 0.891
# ROC-AUC на тестовой выборке: 0.925
# Accuracy: 0.908
# F1-score: 0.872

# %% [markdown]
# Проверим модель на адекватность с помощью DummyClassifier():

# %%
dummy_model = DummyClassifier(random_state=RANDOM_STATE)
dummy_model.fit(X_train_final, y_train_le)
dummy_model_preds = dummy_model.predict(X_test_final)
dummy_model_probas = dummy_model.predict_proba(X_test)[:, 1]

#посчитаем метрику accuracy
dummy_acc = accuracy_score(y_test_le, dummy_model_preds)
print('Dummy Accuracy =', round(dummy_acc,2))

#посчитаем метрику ROC-AUC
dummy_roc = roc_auc_score(y_test_le, dummy_model_probas)
print('ROC-AUC =', round(dummy_roc,2))

#посчитаем F1-меру
dummy_f1 = f1_score(y_test_le, dummy_model_preds, pos_label=1)
print('F1-score =', round(dummy_f1,2))
# Out:
# Dummy Accuracy = 0.62
# ROC-AUC = 0.5
# F1-score = 0.0

# %% [markdown]
# Сравним метрики dummy-модели с нашей лучшей моделью CVC(). Мы видим, что ROC-AUC и F1-мера у SVC() гораздо выше, а значит, она работает адекватно. Перейдем к вкладу признаков.

# %%
explainer = shap.Explainer(best_model, X_test_final)
shap_values = explainer(X_test_final)
shap.plots.bar(shap_values, max_display=20) 
plt.show()

# %% [markdown]
# По графику общей значимости признаков видим, что сильнее всего влияют на целевой признак следующие признаки:
# - страниц_за_визит
# - акционные_покупки
# - минут_предыдущий месяц
# - средний_просмотр_категорий_за_визит
# - минут_текущий_месяц
#
# Наименее значимы для модели в текущем виде такие признаки:
# - маркет_актив_тек_мес
# - разрешить_сообщать
# - популярная_категория_Кухонная_посуда
# - тип_сервиса
#
# При моделировании мы можем сократить наименее значимые признаки и упростить модель, не утратив при этом важную информацию. Для бизнес-решений особую роль играют признаки, которые сильно влияют на пользовательскую активность. Изучим детальнее роль каждого признака на каждое предсказание.

# %%
shap.plots.beeswarm(shap_values, max_display=16)

# %% [markdown]
# Мы видим, что:
# - высокие значения метрики **страниц_за_визит** и **минут_предыдущий_месяц** снижают вероятность отнесения пользователя к классу 1,
# - **акционные_покупки**, наоборот, повышают вероятность того, что пользователя отнесут к классу 1.

# %% [markdown]
# ### Выводы

# %% [markdown]
# Сильнее всего влияют на целевой признак следующие признаки:
# - страниц_за_визит
# - акционные_покупки
# - минут_предыдущий месяц
# - средний_просмотр_категорий_за_визит
# - минут_текущий_месяц
#
# Наименее значимы для модели в текущем виде такие признаки:
# - маркет_актив_тек_мес
# - разрешить_сообщать
# - популярная_категория_Кухонная_посуда
# - тип_сервиса
#
# Чем больше страниц смотрит пользователь за визит и больше минут проводит на сайте, тем лучше его активность: таких пользователей чаще относят к классу 0, то есть тех, чья активность не снижается.
#
# Акционные предложения кажутся спорным способом повысить активность пользователей: чем выше доля таких покупок, тем вероятнее таких покупателей относят к классу людей со снижающейся активностью. Это может быть вызвано тем, что на акции приходят не лояльные покупатели, а покупатели, которые ищут быструю выгоду.

# %% [markdown]
# ## Шаг 8. Сегментация покупателей

# %% [markdown]
# Для сегментации сперва добавим в наш общий датафрейм предсказания лучшей модели в новом столбце, данные из датафрейма df_money. Для этого сперва расширим предсказания на тренировочную выборку, чтобы получить нужную размерность, соберем прогнозы в одном столбце и объединим датафреймы.

# %%
# предсказания для тестовой выборки
clf_best_probas = best_model.predict_proba(X_test_final)[:, 1]
clf_best_probas_train = best_model.predict_proba(X_train_final)[:, 1]

# предсказания для тренировочной выборки
X_pred = best_model.predict(X_train_final)

# создаем DataFrame для тренировочной выборки
train_df = pd.DataFrame(X_train, columns=X.columns)
train_df['покупательская_активность'] = y_train

# создаем DataFrame для тестовой выборки
test_df = pd.DataFrame(X_test, columns=X.columns)
test_df['покупательская_активность'] = y_test

# объединяем выборки
total_train = pd.concat([train_df, pd.Series(clf_best_probas_train, name='принадлежность_к_классу', index=train_df.index), pd.Series(X_pred, name='прогноз_покуп_актив', index=train_df.index)], axis=1)
total_test = pd.concat([test_df, pd.Series(clf_best_probas, name='принадлежность_к_классу', index=test_df.index), pd.Series(y_pred, name='прогноз_покуп_актив', index=test_df.index)], axis=1)

# объединяем данные и добавляем id
final_train = pd.merge(df_merged_final[['id']], total_train, left_index=True, right_index=True)
final_test = pd.merge(df_merged_final[['id']], total_test, left_index=True, right_index=True)

# объединяем тренировочную и тестовую выборки
final_df = pd.concat([final_train, final_test])

# с помощью собственной функции преобразуем числовые значения 'покупательская_активность' в категориальные
final_df['покупательская_активность'] = df_merged_final['покупательская_активность']
final_df['прогноз_покуп_актив'] = final_df['прогноз_покуп_актив'].map({1: 'Снизится', 0: 'Не изменится'})

# добавляем данные о прибыли из df_money
final_df = final_df.merge(df_money, on='id')

# вывод информации о размерности и первых строках
print('Размерность:', final_df.shape)
final_df.head()
# Out:
# Размерность: (1297, 21)
#        id тип_сервиса разрешить_сообщать  маркет_актив_6_мес  \
# 0  215350    стандарт                нет                 4.9
# 1  215352    стандарт                нет                 5.1
# 2  215358    стандарт                 да                 4.7
# 3  215360     премиум                 да                 3.9
# 4  215361    стандарт                 да                 5.1
#
#    маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                     3           539               0.14
# 1                     3          1064               0.94
# 2                     4           450               0.13
# 3                     3           623               0.35
# 4                     4           199               0.23
#
#              популярная_категория  средний_просмотр_категорий_за_визит  \
# 0               Домашний текстиль                                    5
# 1                Товары для детей                                    3
# ...

# %% [markdown]
# Для анализа сегмента выберем группу пользователей, которые должны быть в приоритете по повышению активности. Для них одновременно действуют два условия:
# - приносят высокую прибыль: **прибыль** > 4;
# - скорее всего, их покупательская активность снижается: **принадлежность к классу** > 0.5

# %%
#найдем пользователей, удовлетворяющих условиям, и сохраним в переменной
priority_users = final_df[(final_df['прибыль'] > 4) & (final_df['принадлежность_к_классу'] > 0.5)]
priority_users_stay = final_df[(final_df['прибыль'] > 5) & (final_df['принадлежность_к_классу'] < 0.5)]


#выведем информацию о количестве выбранных пользователей и их первых строк
print('Количество пользователей, удовлетворяющих условиям:', len(priority_users))
priority_users.head()
# Out:
# Количество пользователей, удовлетворяющих условиям: 223
#         id тип_сервиса разрешить_сообщать  маркет_актив_6_мес  \
# 1   215352    стандарт                нет                 5.1
# 3   215360     премиум                 да                 3.9
# 4   215361    стандарт                 да                 5.1
# 7   215368     премиум                 да                 3.8
# 12  215374    стандарт                нет                 2.9
#
#     маркет_актив_тек_мес  длительность  акционные_покупки  \
# 1                      3          1064               0.94
# 3                      3           623               0.35
# 4                      4           199               0.23
# 7                      5           829               0.24
# 12                     5           268               0.98
#
#               популярная_категория  средний_просмотр_категорий_за_визит  \
# 1                 Товары для детей                                    3
# ...

# %% [markdown]
# Теперь визуализируем с помощью нашей функции histbox числовые признаки для этой группы:

# %%
histbox(
    priority_users, 
    exclude_cols=['id'], 
    bins=30, figsize=(10, 40), 
    title_fontsize=14, 
    axis_fontsize=12
)

# %% [markdown]
# ### Промежуточные выводы по распределению числовых признаков выбранного сегмента:

# %% [markdown]
# - Чаще всего на них приходится в среднем 4-5 маркетинговых активностей в месяц;
# - Чаще всего это пользователи-"старички": зарегистрировались более 500 дней назад;
# - Они чаще берут товары по акциям, чем не берут;
# - За визит просматривают 2-3 категории;
# - Сталкиваются с 2-3 сбоями на сайте;
# - За визит смотрят чаще всего четыре страницы;
# - Приносят 5000-6000 выручки в текущем месяце, 5000 в предыдущем, 4600-4800 в предпредыдущем;
# - Проводят все меньше минут на сайте: чаще всего 9 минут в текущем месяце, 10 минут в предыдущем;
# - Скорее всего, большая часть сегмента планирует уйти к конкурентам: очень высокая принадлежность к классу 1 (снижение активности);
# - Обеспечивают самые максимальные показатели прибыли.

# %%
catplot(
    priority_users, 
    exclude_cols=['id'], 
    figsize=(10, 20), 
    title_fontsize=14, 
    axis_fontsize=8
)

# %% [markdown]
# ### Промежуточные выводы по распределению категориальных признаков выбранного сегмента:

# %% [markdown]
# - Мы видим, что пользователи сегмента позитивно относятся к маркетинговым активностям: 74.4% разрешили сообщать им про такие акции;
# - В этом сегменте немного чаще пользуются премиум-сервисом (34% против 28%);
# - Чаще всего пользователи сегмента интересуются товарами для детей, косметикой и аксессуарами, а еще домашним текстилем.
# - Их покупательская активность в большинстве случаев снизится.

# %% [markdown]
# Изучим с помощью гистограммы, у пользователей с каким уровнем прибыльности скорее всего снизится активность.

# %%
kwargs = dict(histtype='bar', bins=25, linewidth=5, ec='black', lw=0.5)
fig, ax = plt.subplots(figsize=(10, 7))
priority_users['прибыль'].plot(kind='hist', alpha=0.9, 
                               facecolor='lightblue', label='Низкая вероятность', **kwargs)
priority_users_stay['прибыль'].plot(kind='hist', alpha=0.6, 
                                    facecolor='salmon', label='Высокая вероятность', **kwargs)

plt.grid(linestyle='dotted', color='g')
plt.title('Как распределяется прибыльность для выбранного сегмента \nс разной вероятностью снижения активности\n', size=15)
plt.xlabel('Прибыльность', size=12)
plt.ylabel('Кол-во покупателей', size=12)
plt.legend(prop={'size': 13}, title='Снижение покупательской активности')

plt.show()

# %% [markdown]
# Мы видим, что снижение активности вероятнее всего затронет пользователей с самой высокой прибыльностью: от 5 и выше (до максимальных значений прибыльности, близких к 7.5). Это может привести к тому, что онлайн-магазин в целом перейдет в более эконом-сегмент: возможно, стоит рассмотреть и такую опция для репозиционирования и укрепления позиций. Ну, или бросить больше усилий на сохранение пользователей с высокой прибыльностью.

# %% [markdown]
# ### Что можно предложить для увеличения активности пользователей сегмента

# %% [markdown]
# **Увеличить число маркетинговых акций**
#
# Мы видим, что пользователи сегмента чаще берут товары по акциям, чем не берут. Кроме того, пользователи сегмента позитивно относятся к маркетинговым активностям: 74.4% разрешили сообщать им про такие акции.
#
# **Использовать в акциях популярные категории**
#
# Чаще всего пользователи сегмента интересуются товарами для детей, косметикой и аксессуарами, а еще домашним текстилем.
#
# **Продвигать премиум-сервис**
#
# В этом сегменте чаще пользуются премиум-сервисом: 34% в сегменте против 28% по нашей выборке пользователей. Премиум-сервис в сегменте может стать дополнительным инструментом для получения прибыли.
#
# **Растить timespent на сайте**
#
# За один визит пользователи сегмента чаще всего просматривают четыре страницы и проводят все меньше минут на сайте: чаще всего 9 минут в текущем месяце, 10 минут в предыдущем. Возможно, стоит подумать над использованием инструментов вовлечения в контент сайта или поработать над UX.

# %% [markdown]
# ## Шаг 8. Общий вывод

# %% [markdown]
# **В рамках проекта выполнили следующие задачи:**
#
# - Построили модель, которая предскажет вероятность снижения покупательской активности клиента в следующие три месяца;
#
# - В исследование включили дополнительные данные финансового департамента о прибыльности клиента: какой доход каждый покупатель приносил компании за последние три месяца;
#
# - Используя данные модели и данные о прибыльности клиентов, выделили приоритетный сегмент покупателей и разработали для него персонализированные предложения.

# %% [markdown]
# **Исходные данные и предобработка:**
#
# - `market_file.csv`: таблица, которая содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
# - `market_money.csv`: таблица с данными о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
# - `market_time.csv`: таблица с данными о времени (в минутах), которое покупатель провёл на сайте в течение периода.
# - `money.csv`: таблица с данными о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
#
#
# 1. Привели столбцы во всех датафреймах к "змеиному регистру" и избавились от пробелов в названиях.
#
# 2. Проверили датафреймы на пропуски, явные и неявные дубликаты и избавились от них.
#
# 3. Проверили, верны ли типы данных в датафреймах. Проблем с ними не обнаружили.

# %% [markdown]
# **Как мы искали лучшую модель:**
#
# 1. Мы разделили данные с учётом страт из-за несбалансированности данных.
# 2. Затем собрали следующий пайплайн:
#
# - Обозначили, какие данные требуют масштабирования, а какие — кодирования, в ohe_columns, ord_columns и num_columns
# - Создали пайплайны для подготовки признаков из списков ohe_columns и ord_columns с помощью OHE-кодирования
# - Создали общий пайплайн data_preprocessor для подготовки данных
# - Создаи итоговый пайплайн pipe_final: подготовка данных и модель
# - С помощью `RandomizedSearchCV` нашли лучшую модель.
#
# **Какие модели использовали:**
#
# - `DecisionTreeClassifier()` с гиперпараметрами max_depth и max_features от 2 до 4 включительно
# - `KNeighborsClassifier()` с гиперпараметрами n_neighbors от 2 до 4 включительно
# - `LogisticRegression()` с решателем solver='liblinear' и лассо-регуляризацией с гиперпараметром С от 1 до 4 включительно
# - `SVC()` с ядрами kernel='linear' и 'rbf'
#
# **Какую метрику использовали:**
#
# За метрику взяли ROC AUC по следующим причинам:
#
# - Хорошо интерпретируется: отображает отношение между долей истинно положительных и долей ложно положительных классификаций при различных порогах
# - Отлично подходит для бинарной классификации с несбалансированной выборкой

# %% [markdown]
# **Лучшая модель:**
#
# - Модель SVC() с RobustScaler() и линеарным ядром.
# - ROC-AUC на тренировочной выборке: 0.891
# - ROC-AUC на тестовой выборке: 0.891
# - Accuracy: 0.908
# - F1-score: 0.872

# %% [markdown]
# **Выводы и дополнительные предложения для выбранного сегмента покупателей:**
#
# Для анализа сегмента выбрали группу пользователей, которые должны быть в приоритете по повышению активности. Для них одновременно действуют два условия:
# - приносят высокую прибыль: **прибыль** > 4;
# - скорее всего, их покупательская активность снижается: **принадлежность к классу** > 0.5
#
# **Увеличить число маркетинговых акций**
#
# Мы видим, что пользователи сегмента чаще берут товары по акциям, чем не берут. Кроме того, пользователи сегмента позитивно относятся к маркетинговым активностям: 74.4% разрешили сообщать им про такие акции.
#
# **Использовать в акциях популярные категории**
#
# Чаще всего пользователи сегмента интересуются товарами для детей, косметикой и аксессуарами, а еще домашним текстилем.
#
# **Продвигать премиум-сервис**
#
# В этом сегменте чаще пользуются премиум-сервисом: 34% в сегменте против 28% по нашей выборке пользователей. Премиум-сервис в сегменте может стать дополнительным инструментом для получения прибыли.
#
# **Растить timespent на сайте**
#
# За один визит пользователи сегмента чаще всего просматривают четыре страницы и проводят все меньше минут на сайте: чаще всего 9 минут в текущем месяце, 10 минут в предыдущем. Возможно, стоит подумать над использованием инструментов вовлечения в контент сайта или поработать над UX.
